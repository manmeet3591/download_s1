# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install rioxarray
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 63.8 MB/s eta 0:00:00
# ...

# %%
# !ls /content/drive/MyDrive/flood/s1_VV_gillespie_2015-03-18_GeoTIFF.tif -lrt
# Out:
# -rw------- 1 root root 2693169058 Nov  8 00:32 /content/drive/MyDrive/flood/s1_VV_gillespie_2015-03-18_GeoTIFF.tif

# %%
import rioxarray

# Replace 'path_to_file.tif' with the actual file path
file_path = '/content/drive/MyDrive/flood/s1_VV_gillespie_2015-03-18_GeoTIFF.tif'

# Open the file as an xarray dataset
ds = rioxarray.open_rasterio(file_path)

# Check the dataset
ds
# Out:
# <xarray.DataArray (band: 1, y: 16026, x: 18419)> Size: 2GB
# [295182894 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 147kB -99.29 -99.29 -99.29 ... -97.63 -97.63 -97.63
#   * y            (y) float64 128kB 30.9 30.9 30.9 30.9 ... 29.46 29.46 29.46
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      VV

# %%
import rasterio
from rasterio.plot import show

with rasterio.open(file_path) as src:
    show(src)

# %%
ds.values
# Out:
# array([[[-10.18241966,  -9.47679734,  -9.43130289, ..., -15.12953858,
#          -15.25278368, -14.38443832],
#         [-10.65837165,  -9.24601055,  -9.32336325, ..., -15.65253636,
#          -15.25834099, -14.54915825],
#         [-11.38184825, -10.10429928, -10.6513259 , ..., -14.2621686 ,
#          -12.50098924, -12.78717757],
#         ...,
#         [ -6.37533459,  -7.29703832,  -9.65365477, ..., -11.53328357,
#          -11.53328357, -11.27099524],
#         [ -5.90835273,  -6.45992232,  -9.38446423, ...,  -8.93476378,
#           -8.93476378, -10.56103322],
#         [ -8.13248347,  -7.75438401,  -8.93262433, ...,  -8.0098019 ,
#           -8.0098019 ,  -8.88456139]]])
